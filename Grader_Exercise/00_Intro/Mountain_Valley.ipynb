# %%
print("+------------------------------------------+")
print("|                                /\\        |")
print("|                               /..\\       |")
print("|                              /....\\      |")
print("|                             /......\\     |")
print("|                            /........\\    |")
print("|       __                  /..........\\   |")
print("|      /..\\                /............\\  |")
print("| /\\  /....\\        /\\    /..............\\ |")
print("|/__\\/______\\______/__\\__/________________\\|")
print("|............\\    /....\\/..................|")
print("|.............\\__/.........................|")
print("+------------------------------------------+")
# Out:
# +------------------------------------------+
# |                                /\        |
# |                               /..\       |
# |                              /....\      |
# |                             /......\     |
# |                            /........\    |
# |       __                  /..........\   |
# |      /..\                /............\  |
# | /\  /....\        /\    /..............\ |
# |/__\/______\______/__\__/________________\|
# |............\    /....\/..................|
# |.............\__/.........................|
# +------------------------------------------+
